# %% [markdown]
# # Pull Year of Play by Play

# %%
import pandas as pd 

#Enter desired years of data
YEARS = [2020]

data = pd.DataFrame()

for i in YEARS:  
    #low_memory=False eliminates a warning
    i_data = pd.read_csv('https://github.com/guga31bb/nflfastR-data/blob/master/data/' \
                         'play_by_play_' + str(i) + '.csv.gz?raw=True',
                         compression='gzip', low_memory=False)

    #sort=True eliminates a warning and alphabetically sorts columns
    data = data.append(i_data, sort=True)

#Give each row a unique index
data.reset_index(drop=True, inplace=True)

# %% [markdown]
# Description of columns
# - Transactional, high level columns of interest
# -- game_date : YYYYY-MM-DD
# -- game_id : YYYY_number_awayteam_hometeam
# -- id: global hash?
# -- desc: play by play description
# -- home_team, away_team : Self explanatory
# - Game Specific
# -- game_date
# -- game_half
# -- game_id
# -- game_seconds_remaining
# -- game_stadium
# - Success or Failure/Play
# -- down
# -- drive
# -- drive_end_transition
# -- drive_end_yard_line
# -- drive_ended_with_score
# -- drive_first_downs
# -- drive_game_clock_end
# -- drive_game_clock_start
# -- drive_inside20
# -- drive_play_count
# -- drive_play_id_ended
# -- drive_play_id_started
# -- drive_quarter_end
# -- drive_quarter_start
# -- drive_real_start_time
# -- drive_start_transition
# -- drive_start_yard_line
# -- drive_time_of_possession
# --drive_yards_penalized

# %%
len()
# Out:
# 48330

# %%
len(data.columns)
# Out:
# 340

# %%
for col in data.columns:
    #if col.startswith('drive'):
    print(col)
# Out:
# aborted_play
# air_epa
# air_wpa
# air_yards
# assist_tackle
# assist_tackle_1_player_id
# assist_tackle_1_player_name
# assist_tackle_1_team
# assist_tackle_2_player_id
# assist_tackle_2_player_name
# assist_tackle_2_team
# assist_tackle_3_player_id
# assist_tackle_3_player_name
# assist_tackle_3_team
# assist_tackle_4_player_id
# assist_tackle_4_player_name
# assist_tackle_4_team
# away_coach
# away_score
# away_team
# away_timeouts_remaining
# away_wp
# away_wp_post
# blocked_player_id
# blocked_player_name
# comp_air_epa
# comp_air_wpa
# comp_yac_epa
# comp_yac_wpa
# complete_pass
# cp
# cpoe
# def_wp
# defensive_extra_point_attempt
# defensive_extra_point_conv
# defensive_two_point_attempt
# defensive_two_point_conv
# defteam
# defteam_score
# defteam_score_post
# defteam_timeouts_remaining
# desc
# div_game
# down
# drive
# drive_end_transition
# drive_end_yard_line
# drive_ended_with_score
# drive_first_downs
# drive_game_clock_end
# drive_game_clock_start
# drive_inside20
# ...

# %%
data[['game_id','desc','id','down','drive','fixed_drive_result','cp']].iloc[20050:21100]
# Out:
#               game_id                                               desc  \
# 20050  2020_08_LV_CLE  (4:18) (Shotgun) 6-B.Mayfield pass short left ...
# 20051  2020_08_LV_CLE  (4:13) (Shotgun) 6-B.Mayfield pass short right...
# 20052  2020_08_LV_CLE  (3:54) (No Huddle, Shotgun) 6-B.Mayfield pass ...
# 20053  2020_08_LV_CLE  (3:50) (Shotgun) 6-B.Mayfield pass deep left t...
# 20054  2020_08_LV_CLE  (3:25) (No Huddle, Shotgun) 6-B.Mayfield pass ...
# ...               ...                                                ...
# 21095  2020_08_SF_SEA  (14:12) 5-J.Myers 48 yard field goal is GOOD, ...
# 21096  2020_08_SF_SEA  5-J.Myers kicks 64 yards from SEA 35 to SF 1. ...
# 21097  2020_08_SF_SEA  (14:02) SF #4 Mullens in at QB. (Shotgun) 4-N....
# 21098  2020_08_SF_SEA  (13:35) (Shotgun) 4-N.Mullens pass short left ...
# 21099  2020_08_SF_SEA    (12:59) 4-N.Mullens pass incomplete short left.
#
#                                          id  down  drive fixed_drive_result  \
# ...
