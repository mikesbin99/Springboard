# %% [markdown]
# # EDA of Kaggle Json Data

# %%
import pandas as pd
import numpy as np

import sweetviz as sv
#from autoviz.AutoViz_Class import AutoViz_Class
#import dtale as dtl

import os
import re
import os.path as path

# %config Completer.use_jedi = False

# %%
df_raw_profile = pd.read_json("C://Users///Mike/Google Drive/Code/Springboard//Springboard//capstone main//NFLData//data//profiles_1512362725.022629.json")

# %%
df_raw_profile
# Out:
#        player_id                name position height  weight    current_team  \
# 0           1809     Robert Blackmon       DB    6-0   208.0            None
# 1          23586          Dean Wells       LB    6-3   248.0            None
# 2            355         Kiko Alonso      ILB    6-3   238.0  Miami Dolphins
# 3          18182        Steve Ramsey       QB    6-2   210.0            None
# 4          16250          Cory Nelms       CB    6-0   195.0            None
# ...          ...                 ...      ...    ...     ...             ...
# 25038      17925      Felto Prewitt      C-LB   5-11   207.0            None
# 25039      10762       Eddie Jackson       DB    6-0   190.0            None
# 25040      19343           Ron Sabal      T-G    6-3   245.0            None
# 25041       4880  Darrel Crutchfield       DB    6-0   177.0            None
# 25042      23865     Will Whitticker        G    6-5   338.0            None
#
# ...

# %%
df_raw_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25043 entries, 0 to 25042
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   player_id           25043 non-null  int64
#  1   name                25043 non-null  object
#  2   position            25043 non-null  object
#  3   height              24788 non-null  object
#  4   weight              24927 non-null  float64
#  5   current_team        1881 non-null   object
#  6   birth_date          24879 non-null  object
#  7   birth_place         24151 non-null  object
#  8   death_date          6542 non-null   object
#  9   college             24893 non-null  object
#  10  high_school         23889 non-null  object
#  11  draft_team          15041 non-null  object
#  12  draft_round         15041 non-null  float64
#  13  draft_position      15041 non-null  float64
#  14  draft_year          15041 non-null  float64
# ...

# %%
#EDA using SweetViz
player = sv.analyze(df_raw_profile)

#Saving results to HTML file
player.show_html('player.html')
# Out:
#                                              |                                            | [  0%]   00:00 -> …
# Report player.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
