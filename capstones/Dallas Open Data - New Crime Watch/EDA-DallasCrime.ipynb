# %% [markdown]
# # Dallas Crime Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly as ply
import pandas_profiling as ppf

# %%
pwd
# Out:
# 'C:\\Users\\Mike\\Google Drive\\Code\\Springboard\\Springboard\\capstones\\Dallas Open Data - New Crime Watch'

# %%
raw_crime = pd.read_csv("C:\\Users\\Mike\\Google Drive\\Code\\Springboard\\Springboard\\capstones\\Dallas Open Data - New Crime Watch\\Public Crime Data - 2014 to present - New_Crime_Watch.csv",
                       dtype={'Victim Business Phone':str,
                              'Special Report (Pre-RMS)':str,
                              'Victim Zip Code':str})
# raw_crime = pd.read_csv("C:\\Users\\Mike\\Google Drive\\Code\\Springboard\\Springboard\\capstones\\Dallas Open Data - New Crime Watch\\Public Crime Data - 2014 to present - New_Crime_Watch.csv",
#                         dtype={'X Coordinate': str,
#                               'Y Cordinate': str,
#                           },
#                         infer_datetime_format=True,
#                         low_memory=False)

# %%
raw_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750862 entries, 0 to 750861
# Data columns (total 92 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   Incident Address                           747686 non-null  object
#  1   Zip Code                                   747347 non-null  float64
#  2   Type of Incident                           750862 non-null  object
#  3   Modus Operandi (MO)                        700360 non-null  object
#  4   Victim Condition                           23207 non-null   object
#  5   Victim Injury Description                  33473 non-null   object
#  6   Victim Gender                              470593 non-null  object
#  7   Person Involvement Type                    723225 non-null  object
#  8   Incident Number w/year                     750862 non-null  object
# ...

# %%
raw_crime.iloc[0]
# Out:
# Incident Address                                      7740 MCCALLUM BLVD
# Zip Code                                                         75252.0
# Type of Incident            UNAUTHORIZED USE OF MOTOR VEH - TRUCK OR BUS
# Modus Operandi (MO)      SUSPECT TOOK COMP'S VEHICLE WITHOUT PERMISSION.
# Victim Condition                                                     NaN
#                                              ...
# Y Cordinate                                               7046427.235888
# City                                                              DALLAS
# State                                                                 TX
# Location1              7740 MCCALLUM BLVD\nDALLAS, TX 75252\n(32.9878...
# Update Date                                  2020-12-09 11:18:34.0000000
# Name: 0, Length: 92, dtype: object

# %%
raw_crime['Update Date'] = pd.to_datetime(raw_crime['Update Date'])

# %%
raw_crime.head(2)
# Out:
#      Incident Address  Zip Code                              Type of Incident  \
# 0  7740 MCCALLUM BLVD   75252.0  UNAUTHORIZED USE OF MOTOR VEH - TRUCK OR BUS
# 1   3083 HERSCHEL AVE   75219.0                           PUBLIC INTOXICATION
#
#                                  Modus Operandi (MO) Victim Condition  \
# 0    SUSPECT TOOK COMP'S VEHICLE WITHOUT PERMISSION.              NaN
# 1  AP NATHALIE MONTERO WAS IN PUBLIC AND INTOXICATED              NaN
#
#   Victim Injury Description Victim Gender Person Involvement Type  \
# 0                       NaN           NaN                     NaN
# 1                       NaN           NaN                  Victim
#
#   Incident Number w/year  Year of Incident  ... Victim Age at Offense  \
# 0            069444-2020              2020  ...                   NaN
# 1            003862-2021              2021  ...                   NaN
#
#    NIBRS Group      NIBRS Type Victim Zip Code  X Coordinate   Y Cordinate  \
# ...

# %%
raw_crime['X Coordinate']
# Out:
# 0         2.497997e+06
# 1         2.485524e+06
# 2         2.523380e+06
# 3         2.494608e+06
# 4         2.460356e+06
#               ...
# 750857    2.504783e+06
# 750858    2.491653e+06
# 750859    2.504766e+06
# 750860    2.482083e+06
# 750861    2.465562e+06
# Name: X Coordinate, Length: 750862, dtype: float64

# %%
raw_crime.describe()
# Out:
#             Zip Code  Year of Incident          Watch  Reporting Area  \
# count  747347.000000     750862.000000  750862.000000   732223.000000
# mean    75224.258624       2017.551464       1.934024     3142.572428
# std       196.513305          1.986634       0.838296     1824.635377
# min         0.000000       2005.000000       1.000000     1001.000000
# 25%     75214.000000       2016.000000       1.000000     1247.000000
# 50%     75224.000000       2018.000000       2.000000     3059.000000
# 75%     75236.000000       2019.000000       3.000000     4321.000000
# max     98004.000000       2121.000000       3.000000     9611.000000
#
#                 Beat         Sector  Year1 of Occurrence  Day1 of the Year  \
# count  750546.000000  750058.000000        750862.000000     750862.000000
# mean      415.978257     411.861789          2017.532363        187.996559
# std       196.787268     197.011197             2.039587        105.080468
# ...

# %%
raw_crime_report = ppf.ProfileReport(raw_crime, title='Dallas Crime',dark_mode=True,explorative=True)

# %%
raw_crime_report.to_file("RawCrime.html")
# Out:
# Summarize dataset:   0%|          | 0/106 [00:00<?, ?it/s]
# C:\Users\Mike\.conda\envs\cap1\lib\site-packages\scipy\stats\stats.py:4594: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
